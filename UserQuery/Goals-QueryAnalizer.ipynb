# %%
import goal_estimator as ge
from IPython.core.display import Image 

query = "computer"

num_topics = 25; alpha = 0.3; num_goals = 25
p = ge.goals(query, num_topics, alpha, num_goals)
Image(filename= p + 'image.png')
# Out:
# Generating dictionary, this takes some time, please wait...!
# 	Dictionary created on
#  0.59 seconds.
# 	Dictionary(393 unique tokens)
# Per-query goal proportions (on 0.0 seconds):
#
#
# MAX  9
# analysis completed in
#  2.28 seconds.
