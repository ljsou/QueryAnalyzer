# %%
import intent_estimator as ie

query = "car"

ie.intent(query)
# Out:
# POS Tags:  S NN E
# TriGram:   S-NN-E
# Max Probability Distribution: neg
# Pos: 0.0106319951055
# Neg: 0.989368004895
#
#
#
# The query is: 	informational
# Transactional: 	0.40395218416
# Informational: 	0.459438703821
# Navigational: 	0.136609112019
#
# analysis completed in
#  1.18 seconds.
