# %%
import logging
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s, level=logging.INFO')
logger = logging.getLogger()
logger.disabled = False

from gensim import corpora, models, similarities
import generate_corpora as genco
import lsamodel as lsam
import ldamodel as ldam
import matplotlib.pyplot as plt
import numpy as np
from os import path
import sys
import wordcloud
from IPython.core.display import Image 
import chunker_noun as chn

num_topics = 10;
num_words = 4;


query = "i want to buy a car"
noun = []
noun = chn.extract(query)

print "IT IS ABOUT:", len(noun)

dictionary, corpus = genco.getCorpus(noun[0])
print corpus
print 
tfidf = models.TfidfModel(corpus) # step 1 -- initialize a model
corpus_tfidf = tfidf[corpus]

alpha=0.3
lda = models.ldamodel.LdaModel(corpus, num_topics=25, id2word=dictionary, update_every=1, chunksize=50, passes=1)
lda_2 = models.ldamodel.LdaModel(corpus, num_topics=25, id2word=dictionary, alpha=alpha, update_every=1, chunksize=50, passes=1)
lda_goals = [lda[c] for c in corpus]
lda_goals_2 = [lda_2[c] for c in corpus]

#plt.hist([len(t) for t in lda_goals], np.arange(40))
#plt.ylabel('Nr of Queriees')
#plt.xlabel('Nr of Goals')
#plt.show()

plt.clf()
plt.hist([[len(t) for t in lda_goals], [len(t) for t in lda_goals_2]], np.arange(40))
plt.ylabel('Nr of Queries')
plt.xlabel('Nr of Goals')
plt.text(3, 150, r'default alpha')
plt.text(25, 300, 'alpha='+str(alpha))
plt.show()

#print "LDA GOALS' TOPICS:"
#ldam.viewTopics(lda, num_topics, num_words)

goals_distribution = ldam.perQueryGoalProportions(query, dictionary, lda_2)
max_goal = ldam.viewPerQueryGoalProportions(goals_distribution)

show_goal = lda.show_topic(max_goal)
#print show_goal
new_goal = []
for goal in show_goal:
    weight = goal[0]
    tag = goal[1]
    new_goal.append((tag, weight))
    
# Compute the position of the words.
elements = wordcloud.fit_words(new_goal, width=100, height=100)
# Draw the positioned words to a PNG file.
p = "/media/University/UniversityDisc/2-Master/MasterThesis/EjecucionTesis/Desarrollo/PythonProjects/QueryAnalyzer/Models/"
wordcloud.draw(elements, path.join(p + 'image.png'), width=100, height=100, scale=3)
Image(filename= p + 'image.png')
# Out:
# hola
# ['car']
# IT IS ABOUT: 1
# Generating dictionary, this takes some time, please wait...
# 	Dictionary created on
#  0.1 seconds.
# 	Dictionary(600 unique tokens)
# MmCorpus(435 documents, 600 features, 1948 non-zero entries)
# vec_bow: 	[(111, 1), (128, 1), (546, 1)]
#
# Per-query goal proportions (on 0.0 seconds):
# [(0, 0.029050424267973732), (1, 0.028818796363686804), (2, 0.029011844225065652), (3, 0.029147324099671398), (4, 0.029361031435452406), (5, 0.029062531976828704), (6, 0.028997231406903943), (7, 0.029609587476921689), (8, 0.029141634832050494), (9, 0.029654896453320728), (10, 0.029459296812527187), (11, 0.028725869775079332), (12, 0.029001333642770313), (13, 0.16987187801894296), (14, 0.029481744349936508), (15, 0.029161288867337459), (16, 0.029088397834515341), (17, 0.15444534085876721), (18, 0.029028758611981214), (19, 0.029316055487229306), (20, 0.033041738546319102), (21, 0.028924847692248255), (22, 0.029729312638376817), (23, 0.029398571873545401), (24, 0.029470262452547843)]
#
#
# MAX  13

# %%
import query_analyzer as qa
from IPython.core.display import Image 

query = "i want to buy a dog and car"
num_topics = 25

p = qa.createCourpus(query, num_topics)
Image(filename= p + 'image.png')
# Out:
# Generating dictionary, this takes some time, please wait...!
# ['dog', 'car']
# 2
# Word:  dog
# Word:  car
# 	Dictionary created on
#  0.18 seconds.
# 	Dictionary(939 unique tokens)
# MmCorpus(714 documents, 939 features, 3157 non-zero entries)
# vec_bow: 	[(56, 1), (196, 1), (846, 1), (863, 1)]
#
# Per-query goal proportions (on 0.0 seconds):
# [(0, 0.026274589394521004), (1, 0.026142025975261649), (2, 0.026160824063760885), (3, 0.0267620006136686), (4, 0.027455148805142375), (5, 0.028155118398459213), (6, 0.02644888184325922), (7, 0.026231002546314188), (8, 0.026102262309904794), (9, 0.026096544949413287), (10, 0.02713269062066782), (11, 0.11672535910300848), (12, 0.026795307513937949), (13, 0.026297322934844818), (14, 0.026315844570758702), (15, 0.027314385623861969), (16, 0.026278595217905609), (17, 0.026088568118594623), (18, 0.026087738977830177), (19, 0.12131124077185119), (20, 0.079353588061423522), (21, 0.12283980242208366), (22, 0.028645106946216504), (23, 0.02621083422502803), (24, 0.026775215992281894)]
#
#
# MAX  21
