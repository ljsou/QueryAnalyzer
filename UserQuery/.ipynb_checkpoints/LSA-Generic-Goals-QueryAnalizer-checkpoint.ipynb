# %% [markdown]
# <h1>Generic Goal Modelling (GoMo)</h1>
# A <i>goal model</i> is a type of statistical model for discovering the abstract "goals" that occur in a collection of queries. The algorithms in GoMo, such as <b>Latent Semantic Analysis (LSA)</b>, <b>Latent Dirichlet Allocation (LDA)</b> and <b>Hierarchical Dirichlet Process (HDP)</b>, discover semantic structure of queries, by examining word statistical co-occurrence patterns within a corpus of training documents. These algorithms are unsupervised, which means no human input is necessary – you only need a corpus of plain text documents.

# %%
import generic_gomo as g

model_path = "/media/University/UniversityDisc/2-Master/MasterThesis/EjecucionTesis/Desarrollo/PythonProjects/QueryAnalyzer/Models/"
g.initCorpora(model_path)
# Out:
# Generating dictionary, this takes some time, please wait...
# 	Dictionary created on
#  23.57 seconds.
# 	Dictionary(16287 unique tokens)
# Dictionary(16287 unique tokens)
# MmCorpus(98294 documents, 16287 features, 326719 non-zero entries)

# %%
import generic_gomo as g

train = True
num_topics = 50
model_path = "/media/University/UniversityDisc/2-Master/MasterThesis/EjecucionTesis/Desarrollo/PythonProjects/QueryAnalyzer/Models/"
lsi, tfidf, dictionary, corpus = g.initLSI(train, num_topics, model_path)
# Out:
# True

# %%
import generic_gomo as g
import lsamodel as lsam
from IPython.core.display import Image 

query = "how do I change my profile on aol"
g.LSI(dictionary, tfidf, lsi, query, model_path)
Image(filename = model_path + 'lsa-image.png')
# Out:
# Init drawTags
# vec_bow: 	[(8281, 1), (8796, 1), (14918, 1), (16179, 1)]
# vec_tfidf:	[(8281, 0.6220427665944339), (8796, 0.5169451955527377), (14918, 0.3893903686667889), (16179, 0.4406876468793137)]
#
# Per-query goal proportions (on 0.0 seconds):
# 	[(0, 0.0051679568489937195), (1, 0.0022642480021670126), (2, 0.0019300277478192217), (3, 0.0046957788171925474), (4, 6.7740763071419933e-05), (5, 0.00051443633223257918), (6, -0.0012105315697731925), (7, 0.00043820340205151119), (8, -0.00077855677909508718), (9, 0.0023097898451712884), (10, 0.0028126250940185161), (11, 0.0017161347760188059), (12, 0.0019580906271806022), (13, 0.0043520397522297119), (14, -0.0012739210286006461), (15, 0.0032483044308677066), (16, 0.0051230263764868011), (17, 0.0041356790883002774), (18, 0.0021286222201372632), (19, 0.0027717026199503771), (20, -0.0001225020971682875), (21, -0.0094508938894468132), (22, 0.0020606565088262187), (23, -0.0054135371334555777), (24, -0.00020920680268308946), (25, 0.0075629258903186503), (26, -0.0061335340685493983), (27, -0.0061362750277436338), (28, 0.0048393243570649504), (29, 0.0075548431812920754), (30, -0.0021079997500380076), (31, -0.0089026384469410632), (32, -0.0055775888631324818), (33, -0.011673743224330499), (34, -0.0038829147518711729), (35, -0.0028234772616870969), (36, -0.0031389300552379842), (37, 0.007970971600598762), (38, -0.010804732586679732), (39, -0.00077665818320509969), (40, -0.0097708625582444419), (41, 0.0019768344852113887), (42, 0.0066078910971505162), (43, 0.0016326300933658113), (44, -0.0035602635359506009), (45, 0.0040855440782536778), (46, -0.00076532596400812134), (47, -0.00037541919490043416), (48, -0.00043337168219280555), (49, -0.00013242203049723385)]
#
#
# MAX: 33
# [(-0.55818415198769766, 'clean'), (-0.53977280187193777, 'draw'), (0.39093862858056011, 'from'), (-0.17902486021239289, 'home'), (0.15860015363953764, 'someone'), (0.14632822939293197, 'build'), (0.13008221221399646, 'learn'), (0.1233133091753438, 'remove'), (-0.11865377696697571, 'house'), (-0.090041812278738642, 'can')]

# %%
import goal_estimator as ge
g.draw_goal(lsi,38)
Image(filename= model_path + 'other_image.png')

# %%
lsi.show_topic(38)
# Out:
# [(-0.50307781242367666, 'getting'),
#  (0.37898118054763957, 'computer'),
#  (-0.33855133580546992, 'profile'),
#  (-0.19865616196512684, 'credit'),
#  (-0.19629066044713472, 'house'),
#  (-0.18428102152657874, 'can'),
#  (0.17762069077501835, 'screen'),
#  (0.17352411385579133, 'check'),
#  (-0.1646934226734737, 'create'),
#  (-0.16247325070067456, 'cleaning')]
