# %% [markdown]
# <h1>Generic Goal Modelling (GoMo)</h1>
# A <i>goal model</i> is a type of statistical model for discovering the abstract "goals" that occur in a collection of queries. The algorithms in GoMo, such as <b>Latent Semantic Analysis (LSA)</b>, <b>Latent Dirichlet Allocation (LDA)</b> and <b>Hierarchical Dirichlet Process (HDP)</b>, discover semantic structure of queries, by examining word statistical co-occurrence patterns within a corpus of training documents. These algorithms are unsupervised, which means no human input is necessary – you only need a corpus of plain text documents.

# %%
import generic_gomo as g

model_path = "/media/University/UniversityDisc/2-Master/MasterThesis/EjecucionTesis/Desarrollo/PythonProjects/QueryAnalyzer/Models/"
g.initCorpora(model_path)
# Out:
# Generating dictionary, this takes some time, please wait...
# 	Dictionary created on
#  23.57 seconds.
# 	Dictionary(16287 unique tokens)
# Dictionary(16287 unique tokens)
# MmCorpus(98294 documents, 16287 features, 326719 non-zero entries)

# %%
import generic_gomo as g

train = False
num_topics = 50
model_path = "/media/University/UniversityDisc/2-Master/MasterThesis/EjecucionTesis/Desarrollo/PythonProjects/QueryAnalyzer/Models/"
lsi, tfidf, dictionary, corpus = g.initLSI(train, num_topics, model_path)
# Out:
# False

# %%
import generic_gomo as g
import lsamodel as lsam
from IPython.core.display import Image 

query = "how do I change my profile on aol"
g.LSI(dictionary, tfidf, lsi, query, model_path)
Image(filename = model_path + 'lsa-image.png')
# Out:
# Init drawTags
# vec_bow: 	[(4642, 1), (5204, 1), (11467, 1), (15660, 1)]
# vec_tfidf:	[(4642, 0.31634066185359305), (5204, 0.5073351814663722), (11467, 0.6494757526633593), (15660, 0.46980937198706096)]
#
# Per-query goal proportions (on 0.0 seconds):
# 	[(0, 0.021331647768035471), (1, 0.06825083039102256), (2, 0.11431544544151923), (3, 0.22193531835816546), (4, -0.0027597712078031348), (5, 0.41218859210973768), (6, -0.0090687607368556133), (7, -0.055450588976971645), (8, 0.3698837267657803), (9, -0.16444354625223132), (10, 0.29295782135813908), (11, 0.0020595615827934607), (12, 0.0085845659076471161), (13, 0.076863605985806993), (14, -0.081200939694359917), (15, -0.0055872661014789802), (16, -0.027382841156160957), (17, -0.080419812331558552), (18, -0.078134169405409876), (19, -0.011481546406467178), (20, -0.034412443144596933), (21, 0.11143641780620273), (22, -0.10613302849870311), (23, -0.057445183687816349), (24, 0.0053593991290784484), (25, -0.076655853431871548), (26, -0.012638459438695146), (27, -0.073996675616837509), (28, 0.059127601535896163), (29, 0.082245416835859689), (30, 0.015367854568588442), (31, -0.059857416188697943), (32, -0.0036631888143354415), (33, -0.079725137080672526), (34, 0.0070917847927069594), (35, -0.0054502439777551898), (36, 0.12722824341080824), (37, 0.0028173627571722454), (38, -0.35006688440502159), (39, -0.33582672868569469), (40, 0.19635551286926162), (41, -0.049580261057045605), (42, -0.059126466545390867), (43, -0.11558752966906523), (44, 0.080634839324387961), (45, -0.067747709257700114), (46, 0.0019010393504617328), (47, -0.051217542283595131), (48, 0.0023454930492410112), (49, -0.0023745778765158669)]
#
#
# MAX: 5
# [(0.73037165347092092, 'do'), (-0.56310445693975175, 'get'), (0.18792246946609398, 'aol'), (0.15396216821498221, 'change'), (-0.10183233807399161, 'find'), (0.097495798767269187, 'account'), (0.087641138037998736, 'know'), (0.070038156712310534, 'password'), (-0.06730463448659002, 'make'), (0.064415906773841014, 'screen')]

# %%
import goal_estimator as ge
g.draw_goal(lsi,38)
Image(filename= model_path + 'other_image.png')

# %%
lsi.show_topic(38)
# Out:
# [(-0.50307781242367666, 'getting'),
#  (0.37898118054763957, 'computer'),
#  (-0.33855133580546992, 'profile'),
#  (-0.19865616196512684, 'credit'),
#  (-0.19629066044713472, 'house'),
#  (-0.18428102152657874, 'can'),
#  (0.17762069077501835, 'screen'),
#  (0.17352411385579133, 'check'),
#  (-0.1646934226734737, 'create'),
#  (-0.16247325070067456, 'cleaning')]
